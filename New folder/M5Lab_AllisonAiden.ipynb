# %%
import pandas as pd
import matplotlib.pyplot

# %%
health_df = pd.read_csv("countyhealth.csv")

# %%
pop_df = pd.read_csv("countypop.csv", index_col="Towncode")

# %%
monthly_infections = health_df.pivot(index="Date",columns="Towncode",values="Cases")

# %%
#Create a linechart showing infections overtime for all cities
monthly_infections.plot()
plt.title("Infections overtime in all counties")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 3
#       1 #Create a linechart showing infections overtime for all cities
#       2 monthly_infections.plot()
# ----> 3 plot.title("Infections overtime in all counties")
#
# NameError: name 'plot' is not defined

# %%
plt.title("Infections overtime in all counties")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 plt.title("Infections overtime in all counties")
#
# NameError: name 'plt' is not defined
